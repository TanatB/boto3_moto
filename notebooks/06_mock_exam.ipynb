# %% [markdown]
# # 06 — Mock Exam
#
# 15 problems covering S3, Glue, Athena, and EC2. No hints or solutions here — solve them as if in a live interview.
#
# **Rules:**
# - Use `with mock_aws():` for every problem
# - Use `helpers.make_boto3_client()` (no real credentials needed)
# - Write clean, runnable code with at least one assertion
# - Problems are roughly ordered by difficulty
#
# ```python
# import sys
# sys.path.insert(0, "..")
# import helpers
# import boto3, pandas as pd
# from moto import mock_aws
# ```

# %%
import sys
sys.path.insert(0, "..")
import helpers

import boto3
import pandas as pd
from moto import mock_aws

# %% [markdown]
# ---
# ## Problem 1 — [S3] Versioned bucket with prefix listing
#
# Create a bucket named `interview-data-lake` with versioning **enabled**. Upload exactly 3 objects with keys that start with `raw/` (any content). Then list all objects under the `raw/` prefix and assert that exactly 3 are returned.

# %%
# YOUR ANSWER HERE

# %% [markdown]
# ---
# ## Problem 2 — [S3] DataFrame Parquet round-trip
#
# Create a DataFrame with at least 10 rows and 3 columns. Upload it to S3 as a Parquet file. Download it back and assert the shape matches the original.

# %%
# YOUR ANSWER HERE

# %% [markdown]
# ---
# ## Problem 3 — [S3] Paginated object listing
#
# Write a function `list_all_objects(s3_client, bucket, prefix)` that returns ALL objects matching a prefix, handling pagination correctly (do not assume all results fit in one response). Test it by uploading 5 objects and calling your function.

# %%
# YOUR ANSWER HERE

# %% [markdown]
# ---
# ## Problem 4 — [S3] Server-side copy across prefixes
#
# Upload 3 CSV files to `raw/` prefix. Copy all of them to `archive/` prefix **without downloading them locally** (use `copy_object`). Assert that both `raw/` and `archive/` contain 3 objects each.

# %%
# YOUR ANSWER HERE

# %% [markdown]
# ---
# ## Problem 5 — [Glue] Create table and return column names
#
# Create a Glue database and a table with at least 4 columns (including a partition column named `dt` of type `string`). Write a function `get_column_names(glue_client, db, table)` that returns the non-partition column names as a Python list.

# %%
# YOUR ANSWER HERE

# %% [markdown]
# ---
# ## Problem 6 — [Glue] Batch partition creation
#
# Create a partitioned Glue table (partition key `dt STRING`). Add partitions for `dt = 2024-01-01`, `2024-01-02`, `2024-01-03` using a **single** `batch_create_partition` call. Then retrieve all partitions and print their values.

# %%
# YOUR ANSWER HERE

# %% [markdown]
# ---
# ## Problem 7 — [Glue] ETL job run polling
#
# Create a Glue ETL job named `my-etl-job`. Start a run with one custom argument `--date=2024-01-15`. Write a loop that polls `get_job_run` until the `JobRunState` is no longer `RUNNING` or `STARTING`. Print the final state.

# %%
# YOUR ANSWER HERE

# %% [markdown]
# ---
# ## Problem 8 — [Athena] Workgroup + query lifecycle
#
# Create an Athena workgroup named `exam-wg` with an S3 output location. Start a query `SELECT COUNT(*) FROM orders`. Poll `get_query_execution` until the state is `SUCCEEDED` or `FAILED`. Print the final state.

# %%
# YOUR ANSWER HERE

# %% [markdown]
# ---
# ## Problem 9 — [Athena] Result injection and DataFrame parsing
#
# Inject 5 mock rows with columns `(city STRING, revenue DOUBLE)` into the moto Athena result queue. Run any query, wait for completion, call `get_query_results`, and parse the output into a DataFrame. Assert: 5 data rows, columns `["city", "revenue"]`, and header row is NOT included as data.

# %%
# YOUR ANSWER HERE

# %% [markdown]
# ---
# ## Problem 10 — [EC2] Launch and filter instances by tag
#
# Launch 3 `t3.micro` instances all tagged `Role=worker`. Launch 1 more instance tagged `Role=master`. Write a function `get_worker_ids(ec2_client)` that returns only the instance IDs where `Role=worker` and state is `running`. Assert it returns exactly 3 IDs.

# %%
# YOUR ANSWER HERE

# %% [markdown]
# ---
# ## Problem 11 — [EC2] Fleet with mixed on-demand + spot
#
# Create a launch template for a data processing node (any AMI, any instance type). Use it to create an EC2 Fleet with **exactly** 2 on-demand and 3 spot instances (5 total). Retrieve the fleet with `describe_fleets` and assert the capacity numbers are correct.

# %%
# YOUR ANSWER HERE

# %% [markdown]
# ---
# ## Problem 12 — [EC2 + S3] Multi-service cleanup
#
# Launch 2 instances tagged `Environment=test`. Create an S3 bucket named `test-artifacts` with 3 objects. Write a function `cleanup_test_environment(ec2_client, s3_client)` that:
# 1. Terminates all instances tagged `Environment=test`
# 2. Empties and deletes the `test-artifacts` bucket
#
# Assert no instances with that tag remain running and the bucket no longer exists.

# %%
# YOUR ANSWER HERE

# %% [markdown]
# ---
# ## Problem 13 — [Glue + Athena] Catalog registration + query
#
# Create a Glue database `exam_db` and a table `sensor_readings` pointing to an S3 location. Register it in an Athena data catalog. Run a query referencing `exam_db.sensor_readings`. Confirm the query execution ID is returned and the state eventually reaches `SUCCEEDED` or `FAILED` (not stuck in `RUNNING`).

# %%
# YOUR ANSWER HERE

# %% [markdown]
# ---
# ## Problem 14 — [Full pipeline] List-of-dicts → Athena COUNT
#
# Write a function:
# ```python
# def count_records(records: list[dict], bucket: str, db: str, table: str) -> int:
#     ...
# ```
# It should:
# 1. Upload the records as a CSV to S3
# 2. Create a Glue table pointing to that S3 path
# 3. Inject a mock Athena result with the correct count
# 4. Run `SELECT COUNT(*) FROM <table>` via Athena
# 5. Parse and return the count as an integer
#
# Test it with 25 records and assert the returned count equals 25.

# %%
# YOUR ANSWER HERE

# %% [markdown]
# ---
# ## Problem 15 — [Design] Daily ingestion pipeline architecture
#
# No code required. Write a markdown description of how you would architect an **automated daily data ingestion pipeline** on AWS using S3, Glue, and Athena. Cover:
#
# 1. How raw data arrives and lands in S3 (partitioning strategy)
# 2. How the Glue catalog is updated (crawler vs. manual partition registration — which do you choose and why?)
# 3. How Athena queries are triggered and monitored
# 4. Retry logic if a step fails
# 5. One specific cost control measure
#
# Keep it under 200 words. This tests verbal communication ability — interviewers weight this heavily.

# %% [markdown]
# **YOUR ANSWER HERE:**
#
# *(Write your architecture description in this markdown cell)*

# %% [markdown]
# ---
# ## Self-Assessment Rubric
#
# | Problem | Topic | Points |
# |---|---|---|
# | 1 | S3 versioning + prefix list | 1 |
# | 2 | S3 Parquet round-trip | 1 |
# | 3 | S3 pagination pattern | 2 |
# | 4 | S3 server-side copy | 2 |
# | 5 | Glue table CRUD | 2 |
# | 6 | Glue batch partitions | 2 |
# | 7 | Glue job polling | 2 |
# | 8 | Athena query lifecycle | 2 |
# | 9 | Athena result injection + parse | 3 |
# | 10 | EC2 launch + tag filter | 2 |
# | 11 | EC2 Fleet mixed capacity | 3 |
# | 12 | Multi-service cleanup | 3 |
# | 13 | Glue + Athena integration | 3 |
# | 14 | Full pipeline function | 4 |
# | 15 | Architecture design | 4 |
# | **Total** | | **36** |
#
# - **32–36**: Interview-ready
# - **24–31**: Review weak areas, redo those notebooks
# - **< 24**: Re-read NB-01 through NB-04, attempt exam again
